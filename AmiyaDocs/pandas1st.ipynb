# %%
import pandas as pd

# %%
df = pd.read_csv("melb_data.csv", nrows = 5, index_col = ["Date"])
df.head()
# Out:
#                Suburb           Address  Rooms Type      Price Method SellerG  \
# Date
# 3/12/2016  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 4/02/2016  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 4/03/2017  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 4/03/2017  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4/06/2016  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#            Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# Date
# 3/12/2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 4/02/2016       2.5    3067.0       2.0       1.0  0.0     156.0
# 4/03/2017       2.5    3067.0       3.0       2.0  0.0     134.0
# 4/03/2017       2.5    3067.0       3.0       2.0  1.0      94.0
# 4/06/2016       2.5    3067.0       3.0       1.0  2.0     120.0
#
#            BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# Date
# ...

# %%
df[["BuildingArea", "YearBuilt"]].isnull()
# Out:
#            BuildingArea  YearBuilt
# Date
# 3/12/2016          True       True
# 4/02/2016         False      False
# 4/03/2017         False      False
# 4/03/2017          True       True
# 4/06/2016         False      False

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
result = [df.dtypes == "object"].index
df[result].describe()
result
# Out:
# --------------------------------------------------------------------
# ValueError                         Traceback (most recent call last)
# <ipython-input-41-703708fbd161> in <module>
#       1 result = [df.dtypes == "object"].index
# ----> 2 df[result].describe()
#       3 result
#
# /usr/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2987     def __getitem__(self, key):
#    2988         key = lib.item_from_zerodim(key)
# -> 2989         key = com.apply_if_callable(key, self)
#    2990
#    2991         if is_hashable(key):
#
# /usr/lib/python3.9/site-packages/pandas/core/common.py in apply_if_callable(maybe_callable, obj, **kwargs)
#     327     """
#     328     if callable(maybe_callable):
# --> 329         return maybe_callable(obj, **kwargs)
#     330
#     331     return maybe_callable
#
# /usr/lib/python3.9/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1440     @final
#    1441     def __nonzero__(self):
# ...

# %%
file["SellerG"].dtypes
# Out:
# dtype('O')

# %%
# !pip install lxml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
url = "http://www.basketball-reference.com/leagues/NBA_2021_per_game.html"
file2 = pd.read_html(url)

# %%
file3 = file2[0]

# %%
file3.head()
# Out:
#   Rk             Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  \
# 0  1   Precious Achiuwa  PF  21  MIA  54   3  12.6  2.1   3.8  ...  .515  1.3
# 1  2       Jaylen Adams  PG  24  MIL   7   0   2.6  0.1   1.1  ...   NaN  0.0
# 2  3       Steven Adams   C  27  NOP  54  54  28.1  3.4   5.4  ...  .442  3.8
# 3  4        Bam Adebayo   C  23  MIA  51  51  33.4  7.2  12.7  ...  .803  2.3
# 4  5  LaMarcus Aldridge   C  35  TOT  26  23  25.9  5.4  11.4  ...  .872  0.7
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  2.3  3.6  0.5  0.3  0.5  0.8  1.6   5.1
# 1  0.4  0.4  0.3  0.0  0.0  0.0  0.1   0.3
# 2  5.2  9.0  2.0  0.9  0.7  1.4  2.0   7.8
# 3  7.0  9.3  5.2  1.0  1.1  2.8  2.3  19.0
# 4  3.8  4.5  1.9  0.4  1.1  1.0  1.8  13.5
#
# [5 rows x 30 columns]

# %%
type(file3)
# Out:
# pandas.core.frame.DataFrame

# %%
len(file3.columns)
# Out:
# 30

# %%
file3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      700 non-null    object
#  1   Player  700 non-null    object
#  2   Pos     700 non-null    object
#  3   Age     700 non-null    object
#  4   Tm      700 non-null    object
#  5   G       700 non-null    object
#  6   GS      700 non-null    object
#  7   MP      700 non-null    object
#  8   FG      700 non-null    object
#  9   FGA     700 non-null    object
#  10  FG%     698 non-null    object
#  11  3P      700 non-null    object
#  12  3PA     700 non-null    object
#  13  3P%     660 non-null    object
#  14  2P      700 non-null    object
#  15  2PA     700 non-null    object
#  16  2P%     693 non-null    object
#  17  eFG%    698 non-null    object
#  18  FT      700 non-null    object
#  19  FTA     700 non-null    object
#  20  FT%     660 non-null    object
# ...

# %%
bb = pd.read_csv("https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv", sep = ';', skiprows= [1, 4, 3])

# %%
bb.head()
# Out:
#    age          job  marital            education  default housing loan  \
# 0   57     services  married          high.school  unknown      no   no
# 1   56     services  married          high.school       no      no  yes
# 2   45     services  married             basic.9y  unknown      no   no
# 3   59       admin.  married  professional.course       no      no   no
# 4   41  blue-collar  married              unknown  unknown      no   no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  telephone   may         mon  ...         1    999         0  nonexistent
# 1  telephone   may         mon  ...         1    999         0  nonexistent
# 2  telephone   may         mon  ...         1    999         0  nonexistent
# 3  telephone   may         mon  ...         1    999         0  nonexistent
# 4  telephone   may         mon  ...         1    999         0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
bb.sort_values("age", ascending = False).head()
# Out:
#        age      job   marital education  default housing loan   contact month  \
# 38452   98  retired   married  basic.4y  unknown     yes   no  cellular   oct
# 38449   98  retired   married  basic.4y  unknown     yes   no  cellular   oct
# 27823   95  retired  divorced  basic.6y       no      no   no  cellular   mar
# 38918   94  retired   married  basic.9y       no      no   no  cellular   nov
# 40447   92  retired   married   unknown       no      no  yes  cellular   aug
#
#       day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 38452         fri  ...         2    999         0  nonexistent         -3.4
# 38449         fri  ...         1      2         2      success         -3.4
# 27823         thu  ...         1    999         0  nonexistent         -1.8
# 38918         wed  ...         1    999         1      failure         -3.4
# 40447         tue  ...         1      3         1      success         -1.7
#
# ...

# %%
bb.tail(2)
# Out:
#        age         job  marital            education default housing loan  \
# 41183   44  technician  married  professional.course      no      no   no
# 41184   74     retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 41183  cellular   nov         fri  ...         1    999         0
# 41184  cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 41183  nonexistent         -1.1          94.767          -50.8      1.028
# 41184      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 41183       4963.6  yes
# 41184       4963.6   no
#
# [2 rows x 21 columns]

# %%
bb2 = bb.rename(columns = {"age":"age_year", "default":"original"}, inplace = False)

# %%
bb2.head()
# Out:
#    age_year        job  marital    education original housing loan    contact  \
# 0        56  housemaid  married     basic.4y       no      no   no  telephone
# 1        57   services  married  high.school  unknown      no   no  telephone
# 2        37   services  married  high.school       no     yes   no  telephone
# 3        40     admin.  married     basic.6y       no      no   no  telephone
# 4        56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
bb2["age_year"].dtypes
# Out:
# dtype('int64')

# %%
bb2.dtypes
# Out:
# age_year            int64
# job                object
# marital            object
# education          object
# original           object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
bb2.isnull().sum()
# Out:
# age_year          0
# job               0
# marital           0
# education         0
# original          0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64
